# %%
import random

# %%
suits = ("hearts", "clubs", "diamonds", "spades")
ranks = ("two", "three", "four", "five", "six", "seven", "eight", "nine", "ten", "jack","queen", "king","ace")

# %%
values = {"two":2, "three":3, "four":4, "five":5, "six":6, "seven":7, "eight":8, "nine":9,
          "ten":10, "jack":10,"queen":10,"king":10,"ace":11}

# %%
class Card:
    def __init__(self,rank,suit):
        self.rank = rank
        self.suit = suit
    def __str__(self):
        return self.rank + self.suit

# %%
class Deck:
    def __init__(self):
        self.deck = []
        for rank in ranks:
            for suit in suits:
                self.deck.append(Card(rank,suit))
    def __str__(self):
        completedeck = ''
        for card in self.deck:
            completedeck += "\n" + card.__str__()
        return "the deck consists of:" + completedeck
        
    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_Card = self.deck.pop()
        return single_Card

# %%
mydeck = Deck()
mydeck.shuffle()
print(mydeck)
# Out:
# the deck consists of:
# eightspades
# queenspades
# fourhearts
# jackhearts
# nineclubs
# jackspades
# twoclubs
# twohearts
# eightclubs
# sixspades
# queenhearts
# threespades
# sevenspades
# ninespades
# tenclubs
# kinghearts
# sevenhearts
# ninediamonds
# queenclubs
# eightdiamonds
# threeclubs
# threehearts
# tenspades
# fourspades
# sixdiamonds
# fivehearts
# fivediamonds
# ninehearts
# tendiamonds
# acespades
# kingclubs
# twodiamonds
# tenhearts
# jackdiamonds
# jackclubs
# threediamonds
# kingdiamonds
# sixclubs
# acediamonds
# fourdiamonds
# aceclubs
# kingspades
# sixhearts
# queendiamonds
# fivespades
# fiveclubs
# eighthearts
# acehearts
# sevenclubs
# fourclubs
# sevendiamonds
# twospades

# %%
print(mydeck)
# Out:
# the deck consists of:
# eightspades
# queenspades
# fourhearts
# jackhearts
# nineclubs
# jackspades
# twoclubs
# twohearts
# eightclubs
# sixspades
# queenhearts
# threespades
# sevenspades
# ninespades
# tenclubs
# kinghearts
# sevenhearts
# ninediamonds
# queenclubs
# eightdiamonds
# threeclubs
# threehearts
# tenspades
# fourspades
# sixdiamonds
# fivehearts
# fivediamonds
# ninehearts
# tendiamonds
# acespades
# kingclubs
# twodiamonds
# tenhearts
# jackdiamonds
# jackclubs
# threediamonds
# kingdiamonds
# sixclubs
# acediamonds
# fourdiamonds
# aceclubs
# kingspades
# sixhearts
# queendiamonds
# fivespades
# fiveclubs
# eighthearts
# acehearts
# sevenclubs
# fourclubs
# sevendiamonds
# twospades

# %%
class Hand:
    def __init__(self):
        self.cards = []
        self.total = 0
        self.aces = 0
        
    def addcard(self,card):
        self.cards.append(card)
        self.total += values[card.rank]
        if card.rank =="ace":
            self.aces += 1
            
    def adjustaces(self):
        while (self.total >= 22 and self.aces > 0 ):
            self.total -= 10
            self.aces -= 1

# %%
class Money:
    def __init__(self,amount,bet):
        self.amount = amount
        self.bet = bet
    def winbet(self):
        self.amount += self.bet
    def losebet(self):
        self.amount -= self.bet

# %%
def takeabet(money):
    while True:
        try: 
            money.bet = (int)(input("how much money do you bet?   "))
        except:
            print("you must provide an int")
        else:
            if (money.bet > money.amount):
                print("your funds are lacking")
            else:
                break

# %%
def hit(deck,hand):
    card = deck.deal()
    hand.addcard(card)
    hand.adjustaces()

# %%
def hitorstand(deck,hand,boolean):
    while boolean:
        x = input("Do you want to hit or stand? Enter h or s    ")
        if x[0].lower() == 'h':
            hit(deck,hand)
        elif x[0].lower() == 's':
            print("Player stands so it's the Dealer's turn")
            boolean = False
        else:
            print("Sorry")
            continue
        break    
    return boolean

# %%
def playerwins(player,dealer,money):
    print("Awesome!! Player wins")
    money.winbet()

# %%
def dealerwins(player,dealer,money):
    print("bad news, dealer wins")
    money.losebet()

# %%
def gameistie(player,dealer,money):
    print("game is a tie")

# %%
def showpartial(player,dealer):
    print("\n Dealer has ")
    print("hidden card")
    print(' ',dealer.cards[1])
    print("\n  Player has", *player.cards, sep = '\n')
    print("\n Player current total",player.total)

# %%
def showall(player,dealer):
    print("\n Dealer has ",  *dealer.cards, sep = '\n')
    print("\nDealer value", dealer.total)
    print("\n Player has ",  *player.cards, sep ='\n')
    print("\nPlayer value", player.total)

# %%
initial = 10000
while True:
        print("welcome to blackjack")
        deck = Deck()
        deck.shuffle()
        player = Hand()
        player.addcard(deck.deal())
        player.addcard(deck.deal())
        dealer = Hand()
        dealer.addcard(deck.deal())
        dealer.addcard(deck.deal())
        
        money = Money(initial,0)
        takeabet(money)
        
        showpartial(player,dealer)
        if player.total == 21:
            print("blackjack,can pay double, stay put")
            playerwins(player, dealer, money)
        
        gamestatus = True
        while gamestatus:
            gamestatus = hitorstand(deck,player,gamestatus)
            showpartial(player,dealer)
            player.adjustaces()
            if player.total > 21 and player.aces == 0:
                dealerwins(player,dealer,money)
                break
        if player.total <= 21:
            print("\n hidden card was", dealer.cards[0])
            while dealer.total < 17:
                hit(deck,dealer)
                showall(player,dealer)
            if dealer.total> 21:
                playerwins(player,dealer,money)
            elif dealer.total > player.total:
                dealerwins(player,dealer,money)
            elif player.total > dealer.total:
                playerwins(player,dealer,money)
            
            else:
                gameistie(player,dealer,money)
        print("\nPlayerwinnings are ",money.amount)  
        newgame = input("do you feel lucky? play again, y or n:  ")
        if newgame[0].lower() == 'y':
            gamestatus = True
            initial = money.amount
            continue
        else:
            print("goodbye, seek help with your gambling addiction")
            break
# Out:
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   queenhearts
#
#   Player has
# eightspades
# threespades
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   queenhearts
#
#   Player has
# eightspades
# threespades
# fivespades
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   queenhearts
#
#   Player has
# eightspades
# threespades
# fivespades
#
#  Player current total 16
#
#  hidden card was ninediamonds
# bad news, dealer wins
#
# Playerwinnings are  9800
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   fivediamonds
#
#   Player has
# aceclubs
# threespades
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fivediamonds
#
#   Player has
# aceclubs
# threespades
# queendiamonds
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fivediamonds
#
#   Player has
# aceclubs
# threespades
# queendiamonds
# queenspades
#
#  Player current total 24
# bad news, dealer wins
#
# Playerwinnings are  9600
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# sevenhearts
# threehearts
#
#  Player current total 10
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# sevenhearts
# threehearts
# fourspades
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# sevenhearts
# threehearts
# fourspades
# jackhearts
#
#  Player current total 24
# bad news, dealer wins
#
# Playerwinnings are  9400
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   tenhearts
#
#   Player has
# sixdiamonds
# kingspades
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   tenhearts
#
#   Player has
# sixdiamonds
# kingspades
#
#  Player current total 16
#
#  hidden card was queenhearts
# bad news, dealer wins
#
# Playerwinnings are  9200
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   sixdiamonds
#
#   Player has
# tenspades
# fourdiamonds
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sixdiamonds
#
#   Player has
# tenspades
# fourdiamonds
# fourspades
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sixdiamonds
#
#   Player has
# tenspades
# fourdiamonds
# fourspades
#
#  Player current total 18
#
#  hidden card was queendiamonds
#
#  Dealer has
# queendiamonds
# sixdiamonds
# tenhearts
#
# Dealer value 26
#
#  Player has
# tenspades
# fourdiamonds
# fourspades
#
# Player value 18
# Awesome!! Player wins
#
# Playerwinnings are  9700
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   400
#
#  Dealer has
# hidden card
#   ninehearts
#
#   Player has
# fiveclubs
# sevenspades
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   ninehearts
#
#   Player has
# fiveclubs
# sevenspades
# kingclubs
#
#  Player current total 22
# bad news, dealer wins
#
# Playerwinnings are  9300
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   300
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# queenspades
# threehearts
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# queenspades
# threehearts
# acespades
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# queenspades
# threehearts
# acespades
# twodiamonds
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# queenspades
# threehearts
# acespades
# twodiamonds
#
#  Player current total 16
#
#  hidden card was jackclubs
# bad news, dealer wins
#
# Playerwinnings are  9000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   sixclubs
#
#   Player has
# kingclubs
# fivespades
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sixclubs
#
#   Player has
# kingclubs
# fivespades
#
#  Player current total 15
#
#  hidden card was acespades
# bad news, dealer wins
#
# Playerwinnings are  8800
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   300
#
#  Dealer has
# hidden card
#   fourspades
#
#   Player has
# sevendiamonds
# sixspades
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourspades
#
#   Player has
# sevendiamonds
# sixspades
# sixdiamonds
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   fourspades
#
#   Player has
# sevendiamonds
# sixspades
# sixdiamonds
#
#  Player current total 19
#
#  hidden card was sixhearts
#
#  Dealer has
# sixhearts
# fourspades
# queenclubs
#
# Dealer value 20
#
#  Player has
# sevendiamonds
# sixspades
# sixdiamonds
#
# Player value 19
# bad news, dealer wins
#
# Playerwinnings are  8500
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# queenhearts
# fourspades
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# queenhearts
# fourspades
#
#  Player current total 14
#
#  hidden card was eightdiamonds
#
#  Dealer has
# eightdiamonds
# fourdiamonds
# sevendiamonds
#
# Dealer value 19
#
#  Player has
# queenhearts
# fourspades
#
# Player value 14
# bad news, dealer wins
#
# Playerwinnings are  8000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   kingdiamonds
#
#   Player has
# fourspades
# fivespades
#
#  Player current total 9
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   kingdiamonds
#
#   Player has
# fourspades
# fivespades
# twohearts
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   kingdiamonds
#
#   Player has
# fourspades
# fivespades
# twohearts
# twospades
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   kingdiamonds
#
#   Player has
# fourspades
# fivespades
# twohearts
# twospades
# sixclubs
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   kingdiamonds
#
#   Player has
# fourspades
# fivespades
# twohearts
# twospades
# sixclubs
#
#  Player current total 19
#
#  hidden card was nineclubs
# game is a tie
#
# Playerwinnings are  8000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   1000
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# sixclubs
# eightclubs
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# sixclubs
# eightclubs
# sixdiamonds
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# sixclubs
# eightclubs
# sixdiamonds
#
#  Player current total 20
#
#  hidden card was fourdiamonds
#
#  Dealer has
# fourdiamonds
# tenclubs
# threediamonds
#
# Dealer value 17
#
#  Player has
# sixclubs
# eightclubs
# sixdiamonds
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  9000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   800
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# sevendiamonds
# threediamonds
#
#  Player current total 10
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# sevendiamonds
# threediamonds
# fourhearts
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# sevendiamonds
# threediamonds
# fourhearts
# sevenclubs
#
#  Player current total 21
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# sevendiamonds
# threediamonds
# fourhearts
# sevenclubs
#
#  Player current total 21
#
#  hidden card was twohearts
#
#  Dealer has
# twohearts
# twoclubs
# sixhearts
#
# Dealer value 10
#
#  Player has
# sevendiamonds
# threediamonds
# fourhearts
# sevenclubs
#
# Player value 21
#
#  Dealer has
# twohearts
# twoclubs
# sixhearts
# tendiamonds
#
# Dealer value 20
#
#  Player has
# sevendiamonds
# threediamonds
# fourhearts
# sevenclubs
#
# Player value 21
# Awesome!! Player wins
#
# Playerwinnings are  9800
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   ninehearts
#
#   Player has
# nineclubs
# acespades
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   ninehearts
#
#   Player has
# nineclubs
# acespades
#
#  Player current total 20
#
#  hidden card was sevenclubs
#
#  Dealer has
# sevenclubs
# ninehearts
# twospades
#
# Dealer value 18
#
#  Player has
# nineclubs
# acespades
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  10400
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   800
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# threespades
# sevenspades
#
#  Player current total 10
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# threespades
# sevenspades
# fivehearts
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# threespades
# sevenspades
# fivehearts
#
#  Player current total 15
#
#  hidden card was kingclubs
# bad news, dealer wins
#
# Playerwinnings are  9600
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   kinghearts
#
#   Player has
# threespades
# ninespades
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   kinghearts
#
#   Player has
# threespades
# ninespades
# sevenhearts
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   kinghearts
#
#   Player has
# threespades
# ninespades
# sevenhearts
#
#  Player current total 19
#
#  hidden card was kingclubs
# bad news, dealer wins
#
# Playerwinnings are  8900
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   acehearts
#
#   Player has
# eighthearts
# fivediamonds
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   acehearts
#
#   Player has
# eighthearts
# fivediamonds
# tenclubs
#
#  Player current total 23
# bad news, dealer wins
#
# Playerwinnings are  8300
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# queenclubs
# sixspades
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# queenclubs
# sixspades
# kingdiamonds
#
#  Player current total 26
# bad news, dealer wins
#
# Playerwinnings are  7600
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   1000
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# jackdiamonds
# kingclubs
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# jackdiamonds
# kingclubs
#
#  Player current total 20
#
#  hidden card was sevenclubs
# Awesome!! Player wins
#
# Playerwinnings are  8600
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# eighthearts
# fourdiamonds
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# eighthearts
# fourdiamonds
# fourhearts
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# eighthearts
# fourdiamonds
# fourhearts
#
#  Player current total 16
#
#  hidden card was jackhearts
#
#  Dealer has
# jackhearts
# threehearts
# jackclubs
#
# Dealer value 23
#
#  Player has
# eighthearts
# fourdiamonds
# fourhearts
#
# Player value 16
# Awesome!! Player wins
#
# Playerwinnings are  9300
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# ninespades
# fourhearts
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# ninespades
# fourhearts
# tenhearts
#
#  Player current total 23
# bad news, dealer wins
#
# Playerwinnings are  8700
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   800
#
#  Dealer has
# hidden card
#   sevenhearts
#
#   Player has
# twohearts
# ninespades
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sevenhearts
#
#   Player has
# twohearts
# ninespades
# queendiamonds
#
#  Player current total 21
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sevenhearts
#
#   Player has
# twohearts
# ninespades
# queendiamonds
#
#  Player current total 21
#
#  hidden card was kingspades
# Awesome!! Player wins
#
# Playerwinnings are  9500
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# eightspades
# fivediamonds
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# eightspades
# fivediamonds
# fiveclubs
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   ninespades
#
#   Player has
# eightspades
# fivediamonds
# fiveclubs
#
#  Player current total 18
#
#  hidden card was sixdiamonds
#
#  Dealer has
# sixdiamonds
# ninespades
# twodiamonds
#
# Dealer value 17
#
#  Player has
# eightspades
# fivediamonds
# fiveclubs
#
# Player value 18
# Awesome!! Player wins
#
# Playerwinnings are  10200
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   tenspades
#
#   Player has
# aceclubs
# sevenclubs
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   tenspades
#
#   Player has
# aceclubs
# sevenclubs
#
#  Player current total 18
#
#  hidden card was kingclubs
# bad news, dealer wins
#
# Playerwinnings are  9500
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   fourhearts
#
#   Player has
# fivediamonds
# fiveclubs
#
#  Player current total 10
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourhearts
#
#   Player has
# fivediamonds
# fiveclubs
# fourclubs
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourhearts
#
#   Player has
# fivediamonds
# fiveclubs
# fourclubs
# sixspades
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   fourhearts
#
#   Player has
# fivediamonds
# fiveclubs
# fourclubs
# sixspades
#
#  Player current total 20
#
#  hidden card was kingclubs
#
#  Dealer has
# kingclubs
# fourhearts
# acediamonds
#
# Dealer value 15
#
#  Player has
# fivediamonds
# fiveclubs
# fourclubs
# sixspades
#
# Player value 20
#
#  Dealer has
# kingclubs
# fourhearts
# acediamonds
# fivehearts
#
# Dealer value 20
#
#  Player has
# fivediamonds
# fiveclubs
# fourclubs
# sixspades
#
# Player value 20
# game is a tie
#
# Playerwinnings are  9500
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   fivehearts
#
#   Player has
# fourhearts
# twospades
#
#  Player current total 6
# Do you want to hit or stand? Enter h or s    h
#  Dealer has
# hidden card
#   fivehearts
#
#   Player has
# fourhearts
# twospades
# kinghearts
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fivehearts
#
#   Player has
# fourhearts
# twospades
# kinghearts
# sixdiamonds
#
#  Player current total 22
# bad news, dealer wins
#
# Playerwinnings are  9000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# eightdiamonds
# sevenclubs
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# eightdiamonds
# sevenclubs
#
#  Player current total 15
#
#  hidden card was fourclubs
#
#  Dealer has
# fourclubs
# jackspades
# sevenhearts
#
# Dealer value 21
#
#  Player has
# eightdiamonds
# sevenclubs
#
# Player value 15
# bad news, dealer wins
#
# Playerwinnings are  8400
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   100
#
#  Dealer has
# hidden card
#   fourhearts
#
#   Player has
# ninehearts
# threeclubs
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourhearts
#
#   Player has
# ninehearts
# threeclubs
# tendiamonds
#
#  Player current total 22
# bad news, dealer wins
#
# Playerwinnings are  8300
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   100
#
#  Dealer has
# hidden card
#   sevenclubs
#
#   Player has
# fourdiamonds
# eightspades
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sevenclubs
#
#   Player has
# fourdiamonds
# eightspades
# threespades
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sevenclubs
#
#   Player has
# fourdiamonds
# eightspades
# threespades
#
#  Player current total 15
#
#  hidden card was tendiamonds
# bad news, dealer wins
#
# Playerwinnings are  8200
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   acespades
#
#   Player has
# jackspades
# kingdiamonds
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   acespades
#
#   Player has
# jackspades
# kingdiamonds
#
#  Player current total 20
#
#  hidden card was ninespades
# game is a tie
#
# Playerwinnings are  8200
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   tendiamonds
#
#   Player has
# nineclubs
# twospades
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   tendiamonds
#
#   Player has
# nineclubs
# twospades
#
#  Player current total 11
#
#  hidden card was tenclubs
# bad news, dealer wins
#
# Playerwinnings are  8000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   400
#
#  Dealer has
# hidden card
#   tendiamonds
#
#   Player has
# fivehearts
# threespades
#
#  Player current total 8
# Do you want to hit or stand? Enter h or s    f
# Sorry
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tendiamonds
#
#   Player has
# fivehearts
# threespades
# threediamonds
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tendiamonds
#
#   Player has
# fivehearts
# threespades
# threediamonds
# twospades
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tendiamonds
#
#   Player has
# fivehearts
# threespades
# threediamonds
# twospades
# sixspades
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   tendiamonds
#
#   Player has
# fivehearts
# threespades
# threediamonds
# twospades
# sixspades
#
#  Player current total 19
#
#  hidden card was jackhearts
# bad news, dealer wins
#
# Playerwinnings are  7600
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   100
#
#  Dealer has
# hidden card
#   eightclubs
#
#   Player has
# tenclubs
# acespades
#
#  Player current total 21
# blackjack,can pay double, stay put
# Awesome!! Player wins
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   eightclubs
#
#   Player has
# tenclubs
# acespades
#
#  Player current total 21
#
#  hidden card was sevendiamonds
#
#  Dealer has
# sevendiamonds
# eightclubs
# jackhearts
#
# Dealer value 25
#
#  Player has
# tenclubs
# acespades
#
# Player value 21
# Awesome!! Player wins
#
# Playerwinnings are  7800
# do you feel lucky? play again, y or n:  n
# goodbye, seek help with your gambling addiction
