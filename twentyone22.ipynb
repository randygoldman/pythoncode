# %%
import random

# %%
suits = ("hearts", "clubs", "diamonds", "spades")
ranks = ("two", "three", "four", "five", "six", "seven", "eight", "nine", "ten", "jack","queen", "king","ace")

# %%
values = {"two":2, "three":3, "four":4, "five":5, "six":6, "seven":7, "eight":8, "nine":9,
          "ten":10, "jack":10,"queen":10,"king":10,"ace":11}

# %%
class Card:
    def __init__(self,rank,suit):
        self.rank = rank
        self.suit = suit
    def __str__(self):
        return self.rank + self.suit

# %%
class Deck:
    def __init__(self):
        self.deck = []
        for rank in ranks:
            for suit in suits:
                self.deck.append(Card(rank,suit))
    def __str__(self):
        completedeck = ''
        for card in self.deck:
            completedeck += "\n" + card.__str__()
        return "the deck consists of:" + completedeck
        
    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_Card = self.deck.pop()
        return single_Card

# %%
mydeck = Deck()
mydeck.shuffle()
print(mydeck)
# Out:
# the deck consists of:
# ninediamonds
# queenclubs
# fourspades
# fourdiamonds
# queenhearts
# sixclubs
# jackclubs
# threespades
# tenhearts
# aceclubs
# kingclubs
# sixdiamonds
# fiveclubs
# sixhearts
# jackdiamonds
# kingspades
# sixspades
# kingdiamonds
# twospades
# queendiamonds
# tenclubs
# acehearts
# twohearts
# sevenhearts
# kinghearts
# twoclubs
# fivediamonds
# ninehearts
# fourhearts
# eightdiamonds
# nineclubs
# queenspades
# eightspades
# tendiamonds
# tenspades
# jackhearts
# acediamonds
# ninespades
# fivehearts
# jackspades
# sevendiamonds
# threeclubs
# sevenclubs
# eightclubs
# threehearts
# threediamonds
# twodiamonds
# fourclubs
# sevenspades
# acespades
# eighthearts
# fivespades

# %%
print(mydeck)
# Out:
# the deck consists of:
# ninediamonds
# queenclubs
# fourspades
# fourdiamonds
# queenhearts
# sixclubs
# jackclubs
# threespades
# tenhearts
# aceclubs
# kingclubs
# sixdiamonds
# fiveclubs
# sixhearts
# jackdiamonds
# kingspades
# sixspades
# kingdiamonds
# twospades
# queendiamonds
# tenclubs
# acehearts
# twohearts
# sevenhearts
# kinghearts
# twoclubs
# fivediamonds
# ninehearts
# fourhearts
# eightdiamonds
# nineclubs
# queenspades
# eightspades
# tendiamonds
# tenspades
# jackhearts
# acediamonds
# ninespades
# fivehearts
# jackspades
# sevendiamonds
# threeclubs
# sevenclubs
# eightclubs
# threehearts
# threediamonds
# twodiamonds
# fourclubs
# sevenspades
# acespades
# eighthearts
# fivespades

# %%
class Hand:
    def __init__(self):
        self.cards = []
        self.total = 0
        self.aces = 0
        
    def addcard(self,card):
        self.cards.append(card)
        self.total += values[card.rank]
        if card.rank =="ace":
            self.aces += 1
            
    def adjustaces(self):
        while (self.total >= 22 and self.aces > 0 ):
            self.total -= 10
            self.aces -= 1

# %%
class Money:
    def __init__(self,amount,bet):
        self.amount = amount
        self.bet = bet
    def winbet(self):
        self.amount += self.bet
    def losebet(self):
        self.amount -= self.bet

# %%
def takeabet(money):
    while True:
        try: 
            money.bet = (int)(input("how much money do you bet?   "))
        except:
            print("you must provide an int")
        else:
            if (money.bet > money.amount):
                print("your funds are lacking")
            else:
                break

# %%
def hit(deck,hand):
    card = deck.deal()
    hand.addcard(card)
    hand.adjustaces()

# %%
def hitorstand(deck,hand):
    global gamestatus
    while True:
        x = input("Do you want to hit or stand? Enter h or s    ")
        if x[0].lower() == 'h':
            hit(deck,hand)
        elif x[0].lower() == 's':
            print("Player stands so it's the Dealer's turn")
            gamestatus = False
        else:
            print("Sorry")
            continue
        break

# %%
def playerwins(player,dealer,money):
    print("Awesome!! Player wins")
    money.winbet()

# %%
def dealerwins(player,dealer,money):
    print("bad news, dealer wins")
    money.losebet()

# %%
def gameistie(player,dealer,money):
    print("game is a tie")

# %%
def showpartial(player,dealer):
    print("\n Dealer has ")
    print("hidden card")
    print(' ',dealer.cards[1])
    print("\n  Player has", *player.cards, sep = '\n')
    print("\n Player current total",player.total)

# %%
def showall(player,dealer):
    print("\n Dealer has ",  *dealer.cards, sep = '\n')
    print("\nDealer value", dealer.total)
    print("\n Player has ",  *player.cards, sep ='\n')
    print("\nPlayer value", player.total)

# %%
initial = 10000
while True:
        print("welcome to blackjack")
        deck = Deck()
        deck.shuffle()
        player = Hand()
        player.addcard(deck.deal())
        player.addcard(deck.deal())
        dealer = Hand()
        dealer.addcard(deck.deal())
        dealer.addcard(deck.deal())
        
        money = Money(initial,0)
        takeabet(money)
        
        showpartial(player,dealer)
        if player.total == 21:
            print("blackjack,can pay double, stay put")
            playerwins(player, dealer, money)
        
        gamestatus = True
        while gamestatus:
            hitorstand(deck,player)
            showpartial(player,dealer)
            player.adjustaces()
            if player.total > 21 and player.aces == 0:
                dealerwins(player,dealer,money)
                break
        if player.total <= 21:
            print("\n hidden card was", dealer.cards[0])
            while dealer.total < 17:
                hit(deck,dealer)
                showall(player,dealer)
            if dealer.total> 21:
                playerwins(player,dealer,money)
            elif dealer.total > player.total:
                dealerwins(player,dealer,money)
            elif player.total > dealer.total:
                playerwins(player,dealer,money)
            
            else:
                gameistie(player,dealer,money)
        print("\nPlayerwinnings are ",money.amount)  
        newgame = input("do you feel lucky? play again, y or n:  ")
        if newgame[0].lower() == 'y':
            gamestatus = True
            initial = money.amount
            continue
        else:
            print("goodbye, seek help with your gambling addiction")
            break
# Out:
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# fivehearts
# fivediamonds
#
#  Player current total 10
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# fivehearts
# fivediamonds
# fourspades
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# fivehearts
# fivediamonds
# fourspades
#
#  Player current total 14
#
#  hidden card was fourdiamonds
#
#  Dealer has
# fourdiamonds
# tenclubs
# jackdiamonds
#
# Dealer value 24
#
#  Player has
# fivehearts
# fivediamonds
# fourspades
#
# Player value 14
# Awesome!! Player wins
#
# Playerwinnings are  10700
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   twospades
#
#   Player has
# kingclubs
# eightdiamonds
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   twospades
#
#   Player has
# kingclubs
# eightdiamonds
#
#  Player current total 18
#
#  hidden card was ninehearts
#
#  Dealer has
# ninehearts
# twospades
# fourspades
#
# Dealer value 15
#
#  Player has
# kingclubs
# eightdiamonds
#
# Player value 18
#
#  Dealer has
# ninehearts
# twospades
# fourspades
# tenhearts
#
# Dealer value 25
#
#  Player has
# kingclubs
# eightdiamonds
#
# Player value 18
# Awesome!! Player wins
#
# Playerwinnings are  11300
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   fivediamonds
#
#   Player has
# jackdiamonds
# fourdiamonds
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fivediamonds
#
#   Player has
# jackdiamonds
# fourdiamonds
# eightdiamonds
#
#  Player current total 22
# bad news, dealer wins
#
# Playerwinnings are  10700
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   sixhearts
#
#   Player has
# fourspades
# fivehearts
#
#  Player current total 9
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sixhearts
#
#   Player has
# fourspades
# fivehearts
# sixspades
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sixhearts
#
#   Player has
# fourspades
# fivehearts
# sixspades
# fivespades
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sixhearts
#
#   Player has
# fourspades
# fivehearts
# sixspades
# fivespades
#
#  Player current total 20
#
#  hidden card was sevenspades
#
#  Dealer has
# sevenspades
# sixhearts
# fourhearts
#
# Dealer value 17
#
#  Player has
# fourspades
# fivehearts
# sixspades
# fivespades
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  11300
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   sixspades
#
#   Player has
# jackhearts
# twohearts
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sixspades
#
#   Player has
# jackhearts
# twohearts
# eightspades
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sixspades
#
#   Player has
# jackhearts
# twohearts
# eightspades
#
#  Player current total 20
#
#  hidden card was fourhearts
#
#  Dealer has
# fourhearts
# sixspades
# sevendiamonds
#
# Dealer value 17
#
#  Player has
# jackhearts
# twohearts
# eightspades
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  12000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   sixhearts
#
#   Player has
# twodiamonds
# tenspades
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sixhearts
#
#   Player has
# twodiamonds
# tenspades
# tendiamonds
#
#  Player current total 22
# bad news, dealer wins
#
# Playerwinnings are  11300
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   ninehearts
#
#   Player has
# fourdiamonds
# tenclubs
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   ninehearts
#
#   Player has
# fourdiamonds
# tenclubs
# sevenspades
#
#  Player current total 21
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   ninehearts
#
#   Player has
# fourdiamonds
# tenclubs
# sevenspades
#
#  Player current total 21
#
#  hidden card was sixhearts
#
#  Dealer has
# sixhearts
# ninehearts
# eightdiamonds
#
# Dealer value 23
#
#  Player has
# fourdiamonds
# tenclubs
# sevenspades
#
# Player value 21
# Awesome!! Player wins
#
# Playerwinnings are  11500
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   queenclubs
#
#   Player has
# kingspades
# jackspades
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   queenclubs
#
#   Player has
# kingspades
# jackspades
#
#  Player current total 20
#
#  hidden card was nineclubs
# Awesome!! Player wins
#
# Playerwinnings are  12000
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   400
#
#  Dealer has
# hidden card
#   queendiamonds
#
#   Player has
# twoclubs
# fourhearts
#
#  Player current total 6
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   queendiamonds
#
#   Player has
# twoclubs
# fourhearts
# fourclubs
#
#  Player current total 10
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   queendiamonds
#
#   Player has
# twoclubs
# fourhearts
# fourclubs
# tenspades
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   queendiamonds
#
#   Player has
# twoclubs
# fourhearts
# fourclubs
# tenspades
#
#  Player current total 20
#
#  hidden card was fivespades
#
#  Dealer has
# fivespades
# queendiamonds
# twodiamonds
#
# Dealer value 17
#
#  Player has
# twoclubs
# fourhearts
# fourclubs
# tenspades
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  12400
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   22
#
#  Dealer has
# hidden card
#   queenhearts
#
#   Player has
# sevenhearts
# sixclubs
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   queenhearts
#
#   Player has
# sevenhearts
# sixclubs
# fivehearts
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   queenhearts
#
#   Player has
# sevenhearts
# sixclubs
# fivehearts
#
#  Player current total 18
#
#  hidden card was threespades
#
#  Dealer has
# threespades
# queenhearts
# eighthearts
#
# Dealer value 21
#
#  Player has
# sevenhearts
# sixclubs
# fivehearts
#
# Player value 18
# bad news, dealer wins
#
# Playerwinnings are  12378
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   33
#
#  Dealer has
# hidden card
#   sevendiamonds
#
#   Player has
# threespades
# sixdiamonds
#
#  Player current total 9
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sevendiamonds
#
#   Player has
# threespades
# sixdiamonds
# acediamonds
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sevendiamonds
#
#   Player has
# threespades
# sixdiamonds
# acediamonds
#
#  Player current total 20
#
#  hidden card was twospades
#
#  Dealer has
# twospades
# sevendiamonds
# jackspades
#
# Dealer value 19
#
#  Player has
# threespades
# sixdiamonds
# acediamonds
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  12411
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   66
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# queendiamonds
# fivehearts
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# queendiamonds
# fivehearts
# acediamonds
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# queendiamonds
# fivehearts
# acediamonds
#
#  Player current total 16
#
#  hidden card was tenhearts
# bad news, dealer wins
#
# Playerwinnings are  12345
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   60
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# aceclubs
# tendiamonds
#
#  Player current total 21
# blackjack,can pay double, stay put
# Awesome!! Player wins
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   jackspades
#
#   Player has
# aceclubs
# tendiamonds
#
#  Player current total 21
#
#  hidden card was acespades
# game is a tie
#
# Playerwinnings are  12405
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   66
#
#  Dealer has
# hidden card
#   twodiamonds
#
#   Player has
# sevenclubs
# sixclubs
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   twodiamonds
#
#   Player has
# sevenclubs
# sixclubs
# sixdiamonds
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   twodiamonds
#
#   Player has
# sevenclubs
# sixclubs
# sixdiamonds
#
#  Player current total 19
#
#  hidden card was jackdiamonds
#
#  Dealer has
# jackdiamonds
# twodiamonds
# sevenhearts
#
# Dealer value 19
#
#  Player has
# sevenclubs
# sixclubs
# sixdiamonds
#
# Player value 19
# game is a tie
#
# Playerwinnings are  12405
