# %%
import random

# %%
suits = ("hearts", "clubs", "diamonds", "spades")
ranks = ("two", "three", "four", "five", "six", "seven", "eight", "nine", "ten", "jack","queen", "king","ace")

# %%
values = {"two":2, "three":3, "four":4, "five":5, "six":6, "seven":7, "eight":8, "nine":9,
          "ten":10, "jack":10,"queen":10,"king":10,"ace":11}

# %%
class Card:
    def __init__(self,rank,suit):
        self.rank = rank
        self.suit = suit
    def __str__(self):
        return self.rank + self.suit

# %%
class Deck:
    def __init__(self):
        self.deck = []
        for rank in ranks:
            for suit in suits:
                self.deck.append(Card(rank,suit))
    def __str__(self):
        completedeck = ''
        for card in self.deck:
            completedeck += "\n" + card.__str__()
        return "the deck consists of:" + completedeck
        
    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_Card = self.deck.pop()
        return single_Card

# %%
mydeck = Deck()
mydeck.shuffle()
print(mydeck)
# Out:
# the deck consists of:
# fivediamonds
# twoclubs
# acehearts
# threespades
# sixclubs
# eightdiamonds
# acespades
# queenspades
# nineclubs
# jackclubs
# jackdiamonds
# queenhearts
# tenclubs
# kingdiamonds
# fourspades
# threehearts
# twohearts
# tenspades
# queendiamonds
# jackhearts
# acediamonds
# fivespades
# kingclubs
# fourdiamonds
# threeclubs
# eighthearts
# fiveclubs
# aceclubs
# sixspades
# threediamonds
# twospades
# fourhearts
# sixdiamonds
# sevenhearts
# jackspades
# sevenspades
# queenclubs
# fourclubs
# sevenclubs
# tendiamonds
# kingspades
# ninediamonds
# eightclubs
# tenhearts
# ninehearts
# ninespades
# twodiamonds
# fivehearts
# eightspades
# sixhearts
# sevendiamonds
# kinghearts

# %%
print(mydeck)
# Out:
# the deck consists of:
# fivediamonds
# twoclubs
# acehearts
# threespades
# sixclubs
# eightdiamonds
# acespades
# queenspades
# nineclubs
# jackclubs
# jackdiamonds
# queenhearts
# tenclubs
# kingdiamonds
# fourspades
# threehearts
# twohearts
# tenspades
# queendiamonds
# jackhearts
# acediamonds
# fivespades
# kingclubs
# fourdiamonds
# threeclubs
# eighthearts
# fiveclubs
# aceclubs
# sixspades
# threediamonds
# twospades
# fourhearts
# sixdiamonds
# sevenhearts
# jackspades
# sevenspades
# queenclubs
# fourclubs
# sevenclubs
# tendiamonds
# kingspades
# ninediamonds
# eightclubs
# tenhearts
# ninehearts
# ninespades
# twodiamonds
# fivehearts
# eightspades
# sixhearts
# sevendiamonds
# kinghearts

# %%
class Hand:
    def __init__(self):
        self.cards = []
        self.total = 0
        self.aces = 0
        
    def addcard(self,card):
        self.cards.append(card)
        self.total += values[card.rank]
        if card.rank =="ace":
            self.aces += 1
            
    def adjustaces(self):
        while (self.total >= 22 and self.aces > 0 ):
            self.total -= 10
            self.aces -= 1

# %%
class Money:
    def __init__(self,amount,bet):
        self.amount = amount
        self.bet = bet
    def winbet(self):
        self.amount += self.bet
    def losebet(self):
        self.amount -= self.bet

# %%
def takeabet(money):
    while True:
        try: 
            money.bet = (int)(input("how much money do you bet?   "))
        except:
            print("you must provide an int")
        else:
            if (money.bet > money.amount):
                print("your funds are lacking")
            else:
                break

# %%
def hit(deck,hand):
    card = deck.deal()
    hand.addcard(card)
    hand.adjustaces()

# %%
def hitorstand(deck,hand):
    global gamestatus
    while True:
        x = input("Do you want to hit or stand? Enter h or s    ")
        if x[0].lower() == 'h':
            hit(deck,hand)
        elif x[0].lower() == 's':
            print("Player stands so it's the Dealer's turn")
            gamestatus = False
        else:
            print("Sorry")
            continue
        break

# %%
def playerwins(player,dealer,money):
    print("Awesome!! Player wins")
    money.winbet()

# %%
def dealerwins(player,dealer,money):
    print("bad news, dealer wins")
    money.losebet()

# %%
def gameistie(player,dealer,money):
    print("game is a tie")

# %%
def showpartial(player,dealer):
    print("\n Dealer has ")
    print("hidden card")
    print(' ',dealer.cards[1])
    print("\n  Player has", *player.cards, sep = '\n')
    print("\n Player current total",player.total)

# %%
def showall(player,dealer):
    print("\n Dealer has ",  *dealer.cards, sep = '\n')
    print("\nDealer value", dealer.total)
    print("\n Player has ",  *player.cards, sep ='\n')
    print("\nPlayer value", player.total)

# %%
initial = 10000
while True:
        print("welcome to blackjack")
        deck = Deck()
        deck.shuffle()
        player = Hand()
        player.addcard(deck.deal())
        player.addcard(deck.deal())
        dealer = Hand()
        dealer.addcard(deck.deal())
        dealer.addcard(deck.deal())
        
        money = Money(initial,0)
        takeabet(money)
        
        showpartial(player,dealer)
        if player.total == 21:
            print("blackjack,can pay double, stay put")
            playerwins(player, dealer, money)
        
        gamestatus = True
        while gamestatus:
            hitorstand(deck,player)
            showpartial(player,dealer)
            player.adjustaces()
            if player.total > 21 and player.aces == 0:
                dealerwins(player,dealer,money)
                break
        if player.total <= 21:
            print("\n hidden card was", dealer.cards[0])
            while dealer.total < 17:
                hit(deck,dealer)
                showall(player,dealer)
            if dealer.total> 21:
                playerwins(player,dealer,money)
            elif dealer.total > player.total:
                dealerwins(player,dealer,money)
            elif player.total > dealer.total:
                playerwins(player,dealer,money)
            
            else:
                showall(player,dealer)
                gameistie(player,dealer,money)
        print("\nPlayerwinnings are ",money.amount)  
        newgame = input("do you feel lucky? play again, y or n:  ")
        if newgame[0].lower() == 'y':
            gamestatus = True
            initial = money.amount
            continue
        else:
            print("goodbye, seek help with your gambling addiction")
            break
# Out:
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   nineclubs
#
#   Player has
# fivespades
# fivehearts
#
#  Player current total 10
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   nineclubs
#
#   Player has
# fivespades
# fivehearts
# sixspades
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   nineclubs
#
#   Player has
# fivespades
# fivehearts
# sixspades
#
#  Player current total 16
#
#  hidden card was fourdiamonds
#
#  Dealer has
# fourdiamonds
# nineclubs
# kingdiamonds
#
# Dealer value 23
#
#  Player has
# fivespades
# fivehearts
# sixspades
#
# Player value 16
# Awesome!! Player wins
#
# Playerwinnings are  10700
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   fourspades
#
#   Player has
# sixclubs
# acehearts
#
#  Player current total 17
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   fourspades
#
#   Player has
# sixclubs
# acehearts
#
#  Player current total 17
#
#  hidden card was tenhearts
#
#  Dealer has
# tenhearts
# fourspades
# sixdiamonds
#
# Dealer value 20
#
#  Player has
# sixclubs
# acehearts
#
# Player value 17
# bad news, dealer wins
#
# Playerwinnings are  10100
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   800
#
#  Dealer has
# hidden card
#   sevenhearts
#
#   Player has
# fivehearts
# ninediamonds
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sevenhearts
#
#   Player has
# fivehearts
# ninediamonds
# fourdiamonds
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sevenhearts
#
#   Player has
# fivehearts
# ninediamonds
# fourdiamonds
#
#  Player current total 18
#
#  hidden card was eightspades
#
#  Dealer has
# eightspades
# sevenhearts
# twospades
#
# Dealer value 17
#
#  Player has
# fivehearts
# ninediamonds
# fourdiamonds
#
# Player value 18
# Awesome!! Player wins
#
# Playerwinnings are  10900
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# kingspades
# ninediamonds
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# kingspades
# ninediamonds
#
#  Player current total 19
#
#  hidden card was ninehearts
#
#  Dealer has
# ninehearts
# threehearts
# fivediamonds
#
# Dealer value 17
#
#  Player has
# kingspades
# ninediamonds
#
# Player value 19
# Awesome!! Player wins
#
# Playerwinnings are  11100
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   400
#
#  Dealer has
# hidden card
#   queenspades
#
#   Player has
# ninehearts
# eightspades
#
#  Player current total 17
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   queenspades
#
#   Player has
# ninehearts
# eightspades
#
#  Player current total 17
#
#  hidden card was eightclubs
# bad news, dealer wins
#
# Playerwinnings are  10700
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   2000
#
#  Dealer has
# hidden card
#   sevendiamonds
#
#   Player has
# kingspades
# jackclubs
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sevendiamonds
#
#   Player has
# kingspades
# jackclubs
#
#  Player current total 20
#
#  hidden card was eightclubs
#
#  Dealer has
# eightclubs
# sevendiamonds
# jackdiamonds
#
# Dealer value 25
#
#  Player has
# kingspades
# jackclubs
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  12700
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# fivehearts
# ninehearts
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# fivehearts
# ninehearts
# ninediamonds
#
#  Player current total 23
# bad news, dealer wins
#
# Playerwinnings are  12200
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   1000
#
#  Dealer has
# hidden card
#   sevenspades
#
#   Player has
# kingdiamonds
# eightspades
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sevenspades
#
#   Player has
# kingdiamonds
# eightspades
#
#  Player current total 18
#
#  hidden card was fivespades
#
#  Dealer has
# fivespades
# sevenspades
# fivediamonds
#
# Dealer value 17
#
#  Player has
# kingdiamonds
# eightspades
#
# Player value 18
# Awesome!! Player wins
#
# Playerwinnings are  13200
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   300
#
#  Dealer has
# hidden card
#   threeclubs
#
#   Player has
# sixhearts
# nineclubs
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   threeclubs
#
#   Player has
# sixhearts
# nineclubs
#
#  Player current total 15
#
#  hidden card was kinghearts
#
#  Dealer has
# kinghearts
# threeclubs
# sevenspades
#
# Dealer value 20
#
#  Player has
# sixhearts
# nineclubs
#
# Player value 15
# bad news, dealer wins
#
# Playerwinnings are  12900
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   750
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# tenspades
# sixdiamonds
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   tenclubs
#
#   Player has
# tenspades
# sixdiamonds
# sevendiamonds
#
#  Player current total 23
# bad news, dealer wins
#
# Playerwinnings are  12150
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   jackdiamonds
#
#   Player has
# sixdiamonds
# twoclubs
#
#  Player current total 8
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   jackdiamonds
#
#   Player has
# sixdiamonds
# twoclubs
# acehearts
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   jackdiamonds
#
#   Player has
# sixdiamonds
# twoclubs
# acehearts
#
#  Player current total 19
#
#  hidden card was nineclubs
#
#  Dealer has
# nineclubs
# jackdiamonds
#
# Dealer value 19
#
#  Player has
# sixdiamonds
# twoclubs
# acehearts
#
# Player value 19
# game is a tie
#
# Playerwinnings are  12150
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   sevenclubs
#
#   Player has
# jackspades
# twodiamonds
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sevenclubs
#
#   Player has
# jackspades
# twodiamonds
# threeclubs
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sevenclubs
#
#   Player has
# jackspades
# twodiamonds
# threeclubs
# fivehearts
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   sevenclubs
#
#   Player has
# jackspades
# twodiamonds
# threeclubs
# fivehearts
#
#  Player current total 20
#
#  hidden card was sevenhearts
#
#  Dealer has
# sevenhearts
# sevenclubs
# eighthearts
#
# Dealer value 22
#
#  Player has
# jackspades
# twodiamonds
# threeclubs
# fivehearts
#
# Player value 20
# Awesome!! Player wins
#
# Playerwinnings are  12650
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   400
#
#  Dealer has
# hidden card
#   jackdiamonds
#
#   Player has
# ninediamonds
# sixspades
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   jackdiamonds
#
#   Player has
# ninediamonds
# sixspades
# acediamonds
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   jackdiamonds
#
#   Player has
# ninediamonds
# sixspades
# acediamonds
#
#  Player current total 16
#
#  hidden card was tenspades
# bad news, dealer wins
#
# Playerwinnings are  12250
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# tendiamonds
# kinghearts
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# tendiamonds
# kinghearts
#
#  Player current total 20
#
#  hidden card was queenhearts
# bad news, dealer wins
#
# Playerwinnings are  12050
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   300
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# ninediamonds
# twohearts
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# ninediamonds
# twohearts
# jackclubs
#
#  Player current total 21
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   threehearts
#
#   Player has
# ninediamonds
# twohearts
# jackclubs
#
#  Player current total 21
#
#  hidden card was threediamonds
#
#  Dealer has
# threediamonds
# threehearts
# jackhearts
#
# Dealer value 16
#
#  Player has
# ninediamonds
# twohearts
# jackclubs
#
# Player value 21
#
#  Dealer has
# threediamonds
# threehearts
# jackhearts
# sixclubs
#
# Dealer value 22
#
#  Player has
# ninediamonds
# twohearts
# jackclubs
#
# Player value 21
# Awesome!! Player wins
#
# Playerwinnings are  12350
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   400
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# sixspades
# ninehearts
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# sixspades
# ninehearts
# fiveclubs
#
#  Player current total 20
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# sixspades
# ninehearts
# fiveclubs
#
#  Player current total 20
#
#  hidden card was ninespades
#
#  Dealer has
# ninespades
# aceclubs
#
# Dealer value 20
#
#  Player has
# sixspades
# ninehearts
# fiveclubs
#
# Player value 20
# game is a tie
#
# Playerwinnings are  12350
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   sixdiamonds
#
#   Player has
# nineclubs
# fourhearts
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sixdiamonds
#
#   Player has
# nineclubs
# fourhearts
# queenclubs
#
#  Player current total 23
# bad news, dealer wins
#
# Playerwinnings are  11850
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   900
#
#  Dealer has
# hidden card
#   sixclubs
#
#   Player has
# threespades
# jackclubs
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   sixclubs
#
#   Player has
# threespades
# jackclubs
# jackhearts
#
#  Player current total 23
# bad news, dealer wins
#
# Playerwinnings are  10950
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   1000
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# queenspades
# threediamonds
#
#  Player current total 13
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# queenspades
# threediamonds
# fivespades
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   twoclubs
#
#   Player has
# queenspades
# threediamonds
# fivespades
#
#  Player current total 18
#
#  hidden card was ninehearts
#
#  Dealer has
# ninehearts
# twoclubs
# twospades
#
# Dealer value 13
#
#  Player has
# queenspades
# threediamonds
# fivespades
#
# Player value 18
#
#  Dealer has
# ninehearts
# twoclubs
# twospades
# jackhearts
#
# Dealer value 23
#
#  Player has
# queenspades
# threediamonds
# fivespades
#
# Player value 18
# Awesome!! Player wins
#
# Playerwinnings are  11950
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   200
#
#  Dealer has
# hidden card
#   nineclubs
#
#   Player has
# tendiamonds
# twohearts
#
#  Player current total 12
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   nineclubs
#
#   Player has
# tendiamonds
# twohearts
# tenspades
#
#  Player current total 22
# bad news, dealer wins
#
# Playerwinnings are  11750
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   fourclubs
#
#   Player has
# sixspades
# threeclubs
#
#  Player current total 9
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourclubs
#
#   Player has
# sixspades
# threeclubs
# twodiamonds
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourclubs
#
#   Player has
# sixspades
# threeclubs
# twodiamonds
# kingclubs
#
#  Player current total 21
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   fourclubs
#
#   Player has
# sixspades
# threeclubs
# twodiamonds
# kingclubs
#
#  Player current total 21
#
#  hidden card was jackhearts
#
#  Dealer has
# jackhearts
# fourclubs
# fourdiamonds
#
# Dealer value 18
#
#  Player has
# sixspades
# threeclubs
# twodiamonds
# kingclubs
#
# Player value 21
# Awesome!! Player wins
#
# Playerwinnings are  12250
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   twodiamonds
#
#   Player has
# twohearts
# twoclubs
#
#  Player current total 4
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   twodiamonds
#
#   Player has
# twohearts
# twoclubs
# sevenhearts
#
#  Player current total 11
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   twodiamonds
#
#   Player has
# twohearts
# twoclubs
# sevenhearts
# eightdiamonds
#
#  Player current total 19
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   twodiamonds
#
#   Player has
# twohearts
# twoclubs
# sevenhearts
# eightdiamonds
#
#  Player current total 19
#
#  hidden card was tenclubs
#
#  Dealer has
# tenclubs
# twodiamonds
# fivediamonds
#
# Dealer value 17
#
#  Player has
# twohearts
# twoclubs
# sevenhearts
# eightdiamonds
#
# Player value 19
# Awesome!! Player wins
#
# Playerwinnings are  12750
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   300
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# eightdiamonds
# tenhearts
#
#  Player current total 18
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   aceclubs
#
#   Player has
# eightdiamonds
# tenhearts
#
#  Player current total 18
#
#  hidden card was sevendiamonds
#
#  Dealer has
# sevendiamonds
# aceclubs
#
# Dealer value 18
#
#  Player has
# eightdiamonds
# tenhearts
#
# Player value 18
# game is a tie
#
# Playerwinnings are  12750
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   500
#
#  Dealer has
# hidden card
#   threespades
#
#   Player has
# twoclubs
# twohearts
#
#  Player current total 4
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   threespades
#
#   Player has
# twoclubs
# twohearts
# jackhearts
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   threespades
#
#   Player has
# twoclubs
# twohearts
# jackhearts
# kingclubs
#
#  Player current total 24
# bad news, dealer wins
#
# Playerwinnings are  12250
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   300
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# fiveclubs
# kingclubs
#
#  Player current total 15
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# fiveclubs
# kingclubs
#
#  Player current total 15
#
#  hidden card was fourspades
#
#  Dealer has
# fourspades
# fourdiamonds
# eighthearts
#
# Dealer value 16
#
#  Player has
# fiveclubs
# kingclubs
#
# Player value 15
#
#  Dealer has
# fourspades
# fourdiamonds
# eighthearts
# jackspades
#
# Dealer value 26
#
#  Player has
# fiveclubs
# kingclubs
#
# Player value 15
# Awesome!! Player wins
#
# Playerwinnings are  12550
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   700
#
#  Dealer has
# hidden card
#   fiveclubs
#
#   Player has
# sixclubs
# queenclubs
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fiveclubs
#
#   Player has
# sixclubs
# queenclubs
# nineclubs
#
#  Player current total 25
# bad news, dealer wins
#
# Playerwinnings are  11850
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   300
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# twoclubs
# threeclubs
#
#  Player current total 5
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# twoclubs
# threeclubs
# acehearts
#
#  Player current total 16
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# twoclubs
# threeclubs
# acehearts
# eighthearts
#
#  Player current total 14
# Do you want to hit or stand? Enter h or s    h
#
#  Dealer has
# hidden card
#   fourdiamonds
#
#   Player has
# twoclubs
# threeclubs
# acehearts
# eighthearts
# queenhearts
#
#  Player current total 24
# bad news, dealer wins
#
# Playerwinnings are  11550
# do you feel lucky? play again, y or n:  y
# welcome to blackjack
# how much money do you bet?   600
#
#  Dealer has
# hidden card
#   kingspades
#
#   Player has
# kingclubs
# acespades
#
#  Player current total 21
# blackjack,can pay double, stay put
# Awesome!! Player wins
# Do you want to hit or stand? Enter h or s    s
# Player stands so it's the Dealer's turn
#
#  Dealer has
# hidden card
#   kingspades
#
#   Player has
# kingclubs
# acespades
#
#  Player current total 21
#
#  hidden card was ninespades
# Awesome!! Player wins
#
# Playerwinnings are  12750
